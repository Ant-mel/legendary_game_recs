# %% [markdown]
# # Natural Language Processing
# Here we will explore only using features created by NLP
#
# This feature will originate from game descriptions, and will be used to make a 'genre' on its own

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append("/Users/antonis/code/Ant-mel/legendary_game_recs/")

import string
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

from sklearn.preprocessing import MultiLabelBinarizer, PowerTransformer
from sklearn.compose import ColumnTransformer

from sklearn.neighbors import KNeighborsRegressor

from preprocessing.preprocess_2_features import keeping_ohe_columns_and_dropping_the_originals, keep_x_OHE_columns

# %%
def nlp_topic(x, vectorizer, lda_model):
    """
    Determines which topic the description belongs to
    Should be used to add topic to a column in the training data
    """
    vectorized_x = vectorizer.transform(pd.Series(x))
    vec_x_array = lda_model.transform(vectorized_x)
    vec_list = vec_x_array[0].tolist()

    return vec_list.index(max(vec_list))

# %%
def yeo_johnson_scaling(X_train, column):
    """
    This scales skewed data, and must be fed X_train and not the entire dataset
    Otherwise you looks visibility on your y, or just make it harder to find
    """
    num_transformer_yeo = PowerTransformer(method='yeo-johnson', standardize=False)

    col_transformer = ColumnTransformer([('num_transformer', num_transformer_yeo,
                                    [column])],
                                    remainder='passthrough')

    transfomed_X_train = pd.DataFrame(col_transformer.fit_transform(X_train))

    return transfomed_X_train

# %%
def preprocess_text(sentence):
    """
    Function to clean description text, tokenize and lemmatize words
    """

    # List of extra stopwords we decided do not help create new genres
    extended_stop_words = ['able','access','across','also','always','another','away',
                        'back','become','best','better','big','box','bring','certain',
                        'clear','close','come','console','content','could','course','digital',
                        'dont','one','two','three','four','five','six','seven','eight','nine',
                        'ten','hundred','thousand','either','enjoy','enough','even','exclusive',
                        'extra','feature','franchise','full','fully','fun','game','gameplay',
                        'genre','get','give','go','good','great','great','greatest','happen',
                        'however','huge','ii','improve','include','increase','inside',
                        'interactive','introduce','instead','involve','know','large','last',
                        'later','launch','lead','let','level','like','little','look','long',
                        'main','may','meet','might','mix','modern','mode','much','must','nan',
                        'name','new','next','need','number','nintendo','official','offer',
                        'object','option','order','original','originally','others','part','pc',
                        'perfect','platform','play','playable','player','playstation','plus',
                        'possible','port','prepare','previous','progress','project','publish',
                        'put','reach','ready','remain','return','screen','scroll','second',
                        'first','third','see','sega','sequel','series','set','several','show',
                        'side','similar','since','small','something','sound','special','start',
                        'stat','state','stay','still','studio','super','take','switch','tell',
                        'test','th','though','throughout','title','together','top','try',
                        'ultimate','unique','update','upon','us','use','version','via','wait',
                        'want','wii','within','without','would','xbox','youll','youre','youve']

    ## define stopwords
    stop_words = stopwords.words('english')
    stop_words.extend(extended_stop_words)

    # Basic cleaning
    sentence = sentence.strip() ## remove whitespaces
    sentence = sentence.lower() ## lowercase
    sentence = ''.join(char for char in sentence if not char.isdigit()) ## remove numbers

    # Advanced cleaning

    # remove punctuation
    for punctuation in string.punctuation:
        sentence = sentence.replace(punctuation, '')

    # tokenize
    tokenized_sentence = word_tokenize(sentence)

    # remove stopwords
    tokenized_sentence_cleaned = [
        w for w in tokenized_sentence if not w in stop_words]


    noun_lemmatized = [
        WordNetLemmatizer().lemmatize(word, pos = "n")
        for word in tokenized_sentence_cleaned]

    lemmatized = [
        WordNetLemmatizer().lemmatize(word, pos = "v")
        for word in noun_lemmatized]

    cleaned_sentence = ' '.join(word for word in lemmatized)

    return cleaned_sentence

# %%
def vectorize_text(data, column, min_df=0.02):
    vectorizer = TfidfVectorizer(min_df=min_df)

    # Fit transform on clean text
    vectorized_descriptions = vectorizer.fit_transform(data[column])

    # Create dataframe of vectorized descriptions
    vectorized_descriptions = pd.DataFrame(
        vectorized_descriptions.toarray(),
        columns = vectorizer.get_feature_names_out())

    return vectorizer, vectorized_descriptions

# %%
def create_nlp_topics_and_append(data, column_to_clean, origin_column, lda_components=30, total_features_to_make=None):
    # Create dataframe of vectorized descriptions
    vectorizer, vectorized_descriptions = vectorize_text(data, column_to_clean)

    # Instantiate LDA model
    lda_model = LatentDirichletAllocation(n_components=lda_components, max_iter = 20, learning_method='online')

    # Fit the LDA on the vectorized documents
    lda_model.fit(vectorized_descriptions)

    # Creating topics column, and encoding into dara
    data['topic'] = data[column_to_clean].apply(nlp_topic, vectorizer = vectorizer, lda_model = lda_model)
    topics = pd.get_dummies(data['topic'])

    if total_features_to_make == None:
        pass
    else:
        topics = keep_x_OHE_columns(topics, total_features_to_make)

    # Creating final df to be split into training data
    concatenated_df = data.drop(columns=[origin_column, column_to_clean, 'topic'], axis=1)
    final_df = pd.concat((concatenated_df, topics), axis=1)

    return final_df

# %%
def topics_from_nlp(data, column_with_text, number_of_topics_to_keep=None, lda_components=30):

    data['clean_text'] = data[column_with_text].apply(preprocess_text)
    topics_nlp_df = create_nlp_topics_and_append(data, column_to_clean='clean_text',
                                                 origin_column=column_with_text, total_features_to_make=number_of_topics_to_keep,
                                                 lda_components=lda_components)

    return topics_nlp_df

# %%
def print_topics(model, vectorizer):
    """
    Allows you to print topics to review performance
    """
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names_out()[i], topic[i])
                        for i in topic.argsort()[:-10 - 1:-1]])

# %%
def model_predict(indicies, model, reference_data, X_train):
    game = X_train[indicies:indicies+1]

    ind_list = list(model.kneighbors(game,n_neighbors=10)[1][0])
    prediction = reference_data.iloc[ind_list]

    return prediction

# %% [markdown]
# Removing all columns, except descriptions.
#
# Later, we will add genre to the NLP features and see if anything improves

# %%
final_data = pd.read_json('../raw_data/final_data')

# Columns we don't need immediately
cols_to_drop = ['title', 'release_date', 'plays', 'playing', 'backlogs', 'wishlist',
       'developers', 'platforms', 'genres',
       'total_reviews', 'main', 'ratings_zero_five',
       'ratings_one_zero', 'ratings_one_five', 'ratings_two_zero',
       'ratings_two_five', 'ratings_three_zero', 'ratings_three_five',
       'ratings_four_zero', 'ratings_four_five', 'ratings_five_zero', 'url',
       'game_id']

final_useful_columns = final_data.drop(columns=cols_to_drop)

# descriptions were an onject, we need them as a string!
final_useful_columns['description'] = final_useful_columns['description'].astype(str)

# %%
# Preprocessing description text
final_useful_columns['clean_text'] = final_useful_columns['description'].apply(preprocess_text)

# %%
# Creating X and y train
final_training_data = topics_from_nlp(final_useful_columns, 'description')
X_train_only_topic = final_training_data.drop(columns='avg_review')
y_train_only_topic = final_training_data['avg_review']

# Scaling X_train
X_train_scaled = yeo_johnson_scaling(X_train_only_topic, 'total_lists')

# Instantiating the model
only_topic_knn = KNeighborsRegressor(n_neighbors=10).fit(X_train_scaled,
                                                       y_train_only_topic)

# %%
# Used to get game index to test model
final_data[(final_data['title'] == 'Call of Duty: Black Ops 4')
               | (final_data['title'] == 'The Legend of Zelda: Breath of the Wild')
              | (final_data['title'] == 'Omori')
              | (final_data['title'] == 'FIFA 21')
              | (final_data['title'] == 'Tetris')
              | (final_data['title'] == 'Sid Meier\'s Civilization V')
              | (final_data['title'] == 'Red Dead Redemption')
              | (final_data['title'] == 'Grand Theft Auto V')
                 | (final_data['title'] == 'Pikmin 4')
              | (final_data['title'] == 'The Sims 4')
              | (final_data['title'] == 'Animal Crossing: New Horizons')]
# Out:
#                                          title   release_date  plays  playing  \
# 841                        Red Dead Redemption  1692230400000     40        6
# 906                                   Pikmin 4  1689897600000   2100      573
# 2583                        Grand Theft Auto V  1655251200000     53        3
# 5919                                   FIFA 21  1602115200000   1600       39
# 6988             Animal Crossing: New Horizons  1584576000000  27000     2100
# 12552  The Legend of Zelda: Breath of the Wild  1488499200000  44000     3500
# 16815                               The Sims 4  1409616000000  13000      666
# 21323               Sid Meier's Civilization V  1285027200000   7300       70
# 36255                                    Omori  1608854400000  11000     1400
# 36689                Call of Duty: Black Ops 4  1539302400000   5100       22
#
#        backlogs  wishlist                                       developers  \
# 841          14        35                  [Double Eleven, Rockstar Games]
# 906        1400      2300                                       [Nintendo]
# 2583          8         2                                               []
# 5919         57        20                  [Electronic Arts, EA Vancouver]
# 6988       1900      1500                         [Nintendo EPD, Nintendo]
# 12552      6900      3600  [Nintendo EPD Production Group No. 3, Nintendo]
# 16815      1100       139               [Electronic Arts, The Sims Studio]
# 21323       506       179                        [2K Games, Firaxis Games]
# 36255      6700      5200                                [OMOCAT, PLAYISM]
# 36689       414       145                           [Treyarch, Activision]
#
#        avg_review                                        genres  \
# 841           4.1                     [Adventure, RPG, Shooter]
# 906           4.3     [Adventure, Real Time Strategy, Strategy]
# 2583          4.3                                            []
# 5919          2.5                            [Simulator, Sport]
# 6988          3.6                                   [Simulator]
# 12552         4.4                      [Adventure, Puzzle, RPG]
# 16815         3.1                              [RPG, Simulator]
# 21323         4.0    [Simulator, Strategy, Turn Based Strategy]
# 36255         4.1  [Adventure, Indie, RPG, Turn Based Strategy]
# 36689         2.3                                     [Shooter]
#
#                                                platforms  ...  \
# 841                     [PlayStation 4, Nintendo Switch]  ...
# 906                                    [Nintendo Switch]  ...
# 2583   [PlayStation 4, Xbox One, PlayStation 5, Xbox ...  ...
# 5919   [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
# 6988                                   [Nintendo Switch]  ...
# 12552                           [Wii U, Nintendo Switch]  ...
# 16815  [Windows PC, Mac, PlayStation 4, Xbox One, Pla...  ...
# 21323                           [Windows PC, Mac, Linux]  ...
# 36255  [Windows PC, Mac, PlayStation 4, Nintendo 3DS,...  ...
# 36689              [Windows PC, PlayStation 4, Xbox One]  ...
#
#       ratings_one_five  ratings_two_zero  ratings_two_five ratings_three_zero  \
# 841                  0                 0                 0                  0
# 906                  5                11                15                 52
# 2583                 0                 0                 0                  1
# 5919                90               176               211                255
# 6988               189               629              1141               2833
# 12552              131               367               563               1257
# 16815              202               617               952               1844
# 21323               20                50               102                376
# 36255              104               191               254                491
# 36689              360               598               554                607
#
#        ratings_three_five  ratings_four_zero  ratings_four_five  \
# 841                     3                  2                  2
# 906                   114                373                520
# 2583                    1                  9                  9
# 5919                  114                 70                 18
# 6988                 3691               4224               1761
# 12552                2163               5236               6908
# 16815                1355                938                206
# 21323                 683               1485                754
# 36255                 766               1552               1587
# 36689                 296                176                 45
#
#        ratings_five_zero                                             url  \
# 841                    1                  /games/red-dead-redemption--2/
# 906                  577                                /games/pikmin-4/
# 2583                   8                   /games/grand-theft-auto-v--2/
# 5919                  12                                 /games/fifa-21/
# 6988                1417            /games/animal-crossing-new-horizons/
# 12552              13704  /games/the-legend-of-zelda-breath-of-the-wild/
# 16815                224                              /games/the-sims-4/
# 21323                570              /games/sid-meier-s-civilization-v/
# 36255               3009                                   /games/omori/
# 36689                 23                /games/call-of-duty-black-ops-4/
#
#        game_id
# 841     260737
# 906      59843
# 2583    239064
# 5919    134101
# 6988    109462
# 12552     7346
# 16815     3212
# 21323      866
# 36255    26673
# 36689    83727
#
# [10 rows x 26 columns]

# %%
model_predict(12552, only_topic_knn, final_data, X_train_scaled)
# Out:
#                                          title   release_date  plays  playing  \
# 12552  The Legend of Zelda: Breath of the Wild  1488499200000  44000     3500
# 3112                                Elden Ring  1645747200000  28000     4800
# 15954                               Bloodborne  1427155200000  24000     1500
# 32679                            Super Metroid   764035200000  14000      394
# 11529                                  Cuphead  1506643200000  27000     1600
# 8281                 Fire Emblem: Three Houses  1564012800000  16000     1300
# 7601              Star Wars Jedi: Fallen Order  1573776000000  21000     1000
# 2384                    Xenoblade Chronicles 3  1659052800000   6100      921
# 28632                     Halo: Combat Evolved  1005782400000  15000      235
# 3785                               Inscryption  1634601600000   9000      793
#
#        backlogs  wishlist                                       developers  \
# 12552      6900      3600  [Nintendo EPD Production Group No. 3, Nintendo]
# 3112       7600      6600       [FromSoftware, Bandai Namco Entertainment]
# 15954      8300      4800      [FromSoftware, Sony Computer Entertainment]
# 32679      4000      1100                      [Playtronic, Nintendo R&D1]
# 11529      6800      3500                                    [Studio MDHR]
# 8281       4700      2000                  [Intelligent Systems, Nintendo]
# 7601       5700      1700         [Respawn Entertainment, Electronic Arts]
# 2384       3600      3100                        [Nintendo, Monolith Soft]
# 28632      1700       572                          [MacSoft Games, Bungie]
# 3785       3900      3100         [Daniel Mullins Games, Devolver Digital]
#
#        avg_review                                             genres  \
# 12552         4.4                           [Adventure, Puzzle, RPG]
# 3112          4.5                                   [Adventure, RPG]
# 15954         4.5                                   [Adventure, RPG]
# 32679         4.3                     [Adventure, Platform, Shooter]
# 11529         4.1                 [Arcade, Indie, Platform, Shooter]
# 8281          4.0  [Adventure, RPG, Strategy, Tactical, Turn Base...
# 7601          3.7                                        [Adventure]
# 2384          4.4                                   [Adventure, RPG]
# 28632         3.8                                          [Shooter]
# 3785          4.1  [Adventure, Card & Board Game, Indie, Puzzle, ...
#
#                                                platforms  ...  \
# 12552                           [Wii U, Nintendo Switch]  ...
# 3112   [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
# 15954                                    [PlayStation 4]  ...
# 32679  [Wii U, Super Famicom, SNES, Wii, New Nintendo...  ...
# 11529  [Windows PC, Mac, PlayStation 4, Xbox One, Nin...  ...
# 8281                                   [Nintendo Switch]  ...
# 7601   [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
# 2384                                   [Nintendo Switch]  ...
# 28632                  [Windows PC, Mac, Xbox, Xbox 360]  ...
# 3785   [Windows PC, Mac, Linux, PlayStation 4, Xbox O...  ...
#
#       ratings_one_five  ratings_two_zero  ratings_two_five ratings_three_zero  \
# 12552              131               367               563               1257
# 3112                66               193               270                703
# 15954               67               186               207                492
# 32679               26                76               137                443
# 11529               69               178               308               1186
# 8281                67               218               345                887
# 7601               132               347               600               1871
# 2384                29                78                93                225
# 28632               89               244               390               1196
# 3785                16                79               131                408
#
#        ratings_three_five  ratings_four_zero  ratings_four_five  \
# 12552                2163               5236               6908
# 3112                 1207               3133               5152
# 15954                 851               2304               3446
# 32679                 884               2092               2092
# 11529                2364               5561               3855
# 8281                 1582               3002               2262
# 7601                 3583               4650               1642
# 2384                  301                633                986
# 28632                1820               2570               1297
# 3785                  743               1687               1460
#
#        ratings_five_zero                                             url  \
# 12552              13704  /games/the-legend-of-zelda-breath-of-the-wild/
# 3112               10720                              /games/elden-ring/
# 15954               9048                              /games/bloodborne/
# 32679               2968                           /games/super-metroid/
# 11529               3128                                 /games/cuphead/
# 8281                1697                /games/fire-emblem-three-houses/
# 7601                 701             /games/star-wars-jedi-fallen-order/
# 2384                2160                  /games/xenoblade-chronicles-3/
# 28632               1305                     /games/halo-combat-evolved/
# 3785                1385                             /games/inscryption/
#
#        game_id
# 12552     7346
# 3112    119133
# 15954     7334
# 32679     1103
# 11529     9061
# 8281     26845
# 7601     74701
# 2384    191411
# 28632      740
# 3785    139090
#
# [10 rows x 26 columns]

# %%
model_predict(5919, only_topic_knn, final_data, X_train_scaled)
# Out:
#                                        title   release_date  plays  playing  \
# 20602                                  Brink  1304985600000   1600        2
# 5919                                 FIFA 21  1602115200000   1600       39
# 29880             WinBack: Covert Operations   943056000000    204       10
# 21189  Grand Theft Auto IV: Complete Edition  1288051200000    948       59
# 36882                               Absolver  1503964800000    932        7
# 27175                      F-Zero: GP Legend  1069977600000    359        7
# 21557        Transformers: War for Cybertron  1277164800000   1300       14
# 32020             Mega Man: The Power Battle   812505600000    608        1
# 35240                        Deus Ex Machina   465436800000     84        3
# 9600                         Project Warlock  1539820800000    429       12
#
#        backlogs  wishlist                           developers  avg_review  \
# 20602       161        38  [Splash Damage, Bethesda Softworks]         1.8
# 5919         57        20      [Electronic Arts, EA Vancouver]         2.5
# 29880       161        64                  [Omega Force, Koei]         3.1
# 21189       349        70     [Rockstar North, Rockstar Games]         4.2
# 36882       260        58          [Sloclap, Devolver Digital]         2.9
# 27175       158        66                              [Suzak]         3.3
# 21557       245       151      [High Moon Studios, Activision]         3.6
# 32020        66        30                             [Capcom]         3.1
# 35240       133       171  [Automata U.K. Limited, Nu Wave UK]         3.7
# 9600        304        77  [Buckshot Software, gaming company]         3.2
#
#                                   genres  \
# 20602                          [Shooter]
# 5919                  [Simulator, Sport]
# 29880                [Shooter, Strategy]
# 21189               [Adventure, Shooter]
# 36882  [Adventure, Fighting, Indie, RPG]
# 27175                           [Racing]
# 21557               [Adventure, Shooter]
# 32020                         [Fighting]
# 35240  [Indie, Music, Puzzle, Simulator]
# 9600         [Adventure, Indie, Shooter]
#
#                                                platforms  ...  \
# 20602              [Windows PC, Xbox 360, PlayStation 3]  ...
# 5919   [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
# 29880                       [Nintendo 64, PlayStation 2]  ...
# 21189              [Windows PC, Xbox 360, PlayStation 3]  ...
# 36882  [Windows PC, Mac, Linux, PlayStation 4, Xbox One]  ...
# 27175                          [Wii U, Game Boy Advance]  ...
# 21557              [Windows PC, Xbox 360, PlayStation 3]  ...
# 32020                                           [Arcade]  ...
# 35240              [Commodore C64/128, ZX Spectrum, MSX]  ...
# 9600   [Windows PC, PlayStation 4, Xbox One, Nintendo...  ...
#
#       ratings_one_five  ratings_two_zero  ratings_two_five ratings_three_zero  \
# 20602              147               195               114                 83
# 5919                90               176               211                255
# 29880                2                12                14                 23
# 21189                2                 5                11                 33
# 36882               32                75               101                134
# 27175                1                10                22                 53
# 21557                8                23                50                133
# 32020                4                23                55                139
# 35240                0                 1                 1                 10
# 9600                 3                27                36                 81
#
#        ratings_three_five  ratings_four_zero  ratings_four_five  \
# 20602                  51                 11                  4
# 5919                  114                 70                 18
# 29880                  25                 16                  5
# 21189                  57                154                109
# 36882                 118                 47                 11
# 27175                  56                 25                  8
# 21557                 246                188                 72
# 32020                  89                 38                  6
# 35240                  13                 24                 10
# 9600                   79                 60                 21
#
#        ratings_five_zero                                           url  \
# 20602                  9                                 /games/brink/
# 5919                  12                               /games/fifa-21/
# 29880                  4             /games/winback-covert-operations/
# 21189                134  /games/grand-theft-auto-iv-complete-edition/
# 36882                  5                              /games/absolver/
# 27175                 11                      /games/f-zero-gp-legend/
# 21557                 51        /games/transformers-war-for-cybertron/
# 32020                 10             /games/mega-man-the-power-battle/
# 35240                  3                       /games/deus-ex-machina/
# 9600                   3                       /games/project-warlock/
#
#        game_id
# 20602      502
# 5919    134101
# 29880    47680
# 21189    27912
# 36882    19333
# 27175     3493
# 21557      555
# 32020     1724
# 35240    26432
# 9600    105738
#
# [10 rows x 26 columns]

# %%
model_predict(36255, only_topic_knn, final_data, X_train_scaled)
# Out:
#                             title   release_date  plays  playing  backlogs  \
# 7643              Death Stranding  1573171200000  14000     1300      7800
# 36255                       Omori  1608854400000  11000     1400      6700
# 19706                     Journey  1331596800000  17000      121      3900
# 14046  Uncharted 4: A Thief's End  1462838400000  20000      240      3900
# 4965                 It Takes Two  1616630400000  13000     1400      3700
# 19228               Borderlands 2  1347926400000  23000      523      4200
# 18962                   Far Cry 3  1354060800000  21000      267      3000
# 3021                        Tunic  1647388800000   5600      619      4100
# 24082  Uncharted: Drake's Fortune  1195171200000  17000      115      1800
# 4031                    Deathloop  1631577600000   6600      477      3800
#
#        wishlist                                         developers  \
# 7643       3000  [Sony Interactive Entertainment, Kojima Produc...
# 36255      5200                                  [OMOCAT, PLAYISM]
# 19706      2400     [Sony Computer Entertainment, ThatGameCompany]
# 14046      1700      [Naughty Dog, Sony Interactive Entertainment]
# 4965       2900               [Hazelight Studios, Electronic Arts]
# 19228       727                       [Gearbox Software, 2K Games]
# 18962       987          [Ubisoft Entertainment, Ubisoft Montreal]
# 3021       3900                          [Andrew Shouldice, Finji]
# 24082       654         [Sony Computer Entertainment, Naughty Dog]
# 4031       2400               [Arkane Studios, Bethesda Softworks]
#
#        avg_review                                        genres  \
# 7643          3.9                     [Adventure, RPG, Shooter]
# 36255         4.1  [Adventure, Indie, RPG, Turn Based Strategy]
# 19706         3.9                         [Adventure, Platform]
# 14046         4.1                          [Adventure, Shooter]
# 4965          4.2                 [Adventure, Platform, Puzzle]
# 19228         3.6                                [RPG, Shooter]
# 18962         3.8                          [Adventure, Shooter]
# 3021          3.9               [Adventure, Indie, Puzzle, RPG]
# 24082         3.1                [Adventure, Platform, Shooter]
# 4031          3.4                          [Adventure, Shooter]
#
#                                                platforms  ...  \
# 7643                         [Windows PC, PlayStation 4]  ...
# 36255  [Windows PC, Mac, PlayStation 4, Nintendo 3DS,...  ...
# 19706    [Windows PC, PlayStation 4, iOS, PlayStation 3]  ...
# 14046                                    [PlayStation 4]  ...
# 4965   [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
# 19228  [Windows PC, Android, Mac, Xbox 360, Linux, Pl...  ...
# 18962              [Windows PC, Xbox 360, PlayStation 3]  ...
# 3021   [Windows PC, Mac, PlayStation 4, Xbox One, Pla...  ...
# 24082                                    [PlayStation 3]  ...
# 4031            [Windows PC, PlayStation 5, Xbox Series]  ...
#
#       ratings_one_five  ratings_two_zero  ratings_two_five ratings_three_zero  \
# 7643               114               292               334                809
# 36255              104               191               254                491
# 19706               77               291               420               1188
# 14046               56               182               263                868
# 4965                44                90               134                507
# 19228              269               657               947               2084
# 18962               93               276               584               1661
# 3021                22               100               138                394
# 24082              273               882              1358               3050
# 4031                93               292               350                769
#
#        ratings_three_five  ratings_four_zero  ratings_four_five  \
# 7643                 1193               2132               1707
# 36255                 766               1552               1587
# 19706                1660               2769               1497
# 14046                1724               3856               3272
# 4965                  999               2293               2199
# 19228                2570               3262               1702
# 18962                2968               3675               1771
# 3021                  553                978                692
# 24082                2505               1477                315
# 4031                 1040               1089                454
#
#        ratings_five_zero                                url  game_id
# 7643                1867            /games/death-stranding/    19564
# 36255               3009                      /games/omori/    26673
# 19706               2037                    /games/journey/     1352
# 14046               2899  /games/uncharted-4-a-thief-s-end/     7331
# 4965                2234               /games/it-takes-two/   135243
# 19228               1579              /games/borderlands-2/     1011
# 18962               1229                  /games/far-cry-3/      529
# 3021                 630                      /games/tunic/    23733
# 24082                266  /games/uncharted-drake-s-fortune/      431
# 4031                 211                  /games/deathloop/   113598
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Evaluation
# Predictions for Breath of the Wild are identical with only genres without scaling, and is much improved after scaling
# Predicitons for Fifa 21 are worse, with Fifa 21 not even being the closest neighbour to itself!!
# Predictions for Omori are better, but could still be improved as Omori also isn't first to itself!!

# %% [markdown]
# ## Mixing NLP Topics with Genres

# %%
def drop_column_and_concat(data, new_columns, column_to_drop):
    new_df = pd.concat((data, new_columns), axis=1)
    new_df.drop(columns=column_to_drop, inplace=True)

    return new_df

ohe_added_to_data = drop_column_and_concat(final_useful_columns, ohe_columns, 'genres')

ohe_and_topics = topics_from_nlp(ohe_added_to_data, 'description', 10)

# %%
def ohe_and_nlp(data, ohe_column_name, n_ohe_features, nlp_column_name, n_nlp_features):
    ohe_columns = keeping_ohe_columns_and_dropping_the_originals(data[[ohe_column_name]], n_ohe_features)

    ohe_added_to_data = drop_column_and_concat(data, ohe_columns, ohe_column_name)

    ohe_and_topics = topics_from_nlp(ohe_added_to_data, nlp_column_name, n_nlp_features)

    return ohe_and_topics

# %%
def train_model(X_train, y_train, neighbours=10):
    model = KNeighborsRegressor(n_neighbors=neighbours).fit(X_train, y_train)

    return model

# %%
final_data = pd.read_json('../raw_data/final_data')

# Columns we don't need immediately
cols_to_drop = ['title', 'release_date', 'plays', 'playing', 'backlogs', 'wishlist',
       'developers', 'platforms',
       'total_reviews', 'main', 'ratings_zero_five',
       'ratings_one_zero', 'ratings_one_five', 'ratings_two_zero',
       'ratings_two_five', 'ratings_three_zero', 'ratings_three_five',
       'ratings_four_zero', 'ratings_four_five', 'ratings_five_zero', 'url',
       'game_id']

final_useful_columns = final_data.drop(columns=cols_to_drop)

# descriptions were an onject, we need them as a string!
final_useful_columns['description'] = final_useful_columns['description'].astype(str)

# %%
ohe_and_topics = ohe_and_nlp(final_useful_columns, 'genres', 20, 'description', 10)
# Out:
# /Users/antonis/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LatentDirichletAllocation was fitted with feature names
#   warnings.warn(

# %%
X_train = yeo_johnson_scaling(ohe_and_topics.drop('avg_review', axis=1), 'total_lists')
y_train = ohe_and_topics['avg_review']

topic_and_genre_model = train_model(X_train, y_train)
# Out:
# /Users/antonis/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/sklearn/utils/validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
model_predict(12552, topic_and_genre_model, final_data, X_train)
# Out:
#                                          title   release_date  plays  playing  \
# 12552  The Legend of Zelda: Breath of the Wild  1488499200000  44000     3500
# 19153                               Dishonored  1349740800000  20000      382
# 30494     The Legend of Zelda: Ocarina of Time   911606400000  24000      682
# 33395            Kaeru no Tame ni Kane wa Naru   719020800000    245       11
# 27827      The Legend of Zelda: The Wind Waker  1039737600000  15000      337
# 28345                           Kingdom Hearts  1017273600000  16000      377
# 25654                        Kingdom Hearts II  1135209600000  13000      172
# 7794                             Disco Elysium  1571097600000   6200      732
# 26948                          Katamari Damacy  1079568000000   5300       86
# 24496   The Legend of Zelda: Phantom Hourglass  1182556800000   8900      134
#
#        backlogs  wishlist                                         developers  \
# 12552      6900      3600    [Nintendo EPD Production Group No. 3, Nintendo]
# 19153      4900      1200               [Arkane Studios, Bethesda Softworks]
# 30494      4600      1900                               [iQue, Nintendo EAD]
# 33395       243       163                                         [Nintendo]
# 27827      4000      1900  [Nintendo EAD Software Development Group No.3,...
# 28345      3100      1400               [Square, Disney Interactive Studios]
# 25654      2300       918                   [Buena Vista Games, Square Enix]
# 7794       4300      2400                                            [ZA/UM]
# 26948      1300       983                           [Keita Takahashi, Namco]
# 24496      2400       824  [Nintendo, Nintendo EAD Software Development G...
#
#        avg_review                    genres  \
# 12552         4.4  [Adventure, Puzzle, RPG]
# 19153         4.0  [Adventure, Puzzle, RPG]
# 30494         4.3          [Adventure, RPG]
# 33395         3.9  [Adventure, Puzzle, RPG]
# 27827         4.2  [Adventure, Puzzle, RPG]
# 28345         3.7          [Adventure, RPG]
# 25654         4.3          [Adventure, RPG]
# 7794          4.5          [Adventure, RPG]
# 26948         4.2       [Adventure, Puzzle]
# 24496         3.3  [Adventure, Puzzle, RPG]
#
#                                    platforms  ... ratings_one_five  \
# 12552               [Wii U, Nintendo Switch]  ...              131
# 19153  [Windows PC, Xbox 360, PlayStation 3]  ...               50
# 30494              [Wii U, Wii, Nintendo 64]  ...               52
# 33395               [Nintendo 3DS, Game Boy]  ...                2
# 27827                    [Nintendo GameCube]  ...               24
# 28345                        [PlayStation 2]  ...              115
# 25654                        [PlayStation 2]  ...               37
# 7794                       [Windows PC, Mac]  ...               10
# 26948         [PlayStation 3, PlayStation 2]  ...               11
# 24496                   [Wii U, Nintendo DS]  ...               98
#
#        ratings_two_zero  ratings_two_five ratings_three_zero  \
# 12552               367               563               1257
# 19153               208               379               1135
# 30494               131               282                835
# 33395                 1                 6                 13
# 27827                92               118                439
# 28345               331               476               1359
# 25654               103               133                353
# 7794                 33                39                 76
# 26948                24                31                162
# 24496               316               507               1184
#
#        ratings_three_five  ratings_four_zero  ratings_four_five  \
# 12552                2163               5236               6908
# 19153                2131               3753               2218
# 30494                1468               3065               2862
# 33395                  36                 50                 26
# 27827                 942               2282               2144
# 28345                2031               2517               1102
# 25654                 650               1717               1623
# 7794                  143                431                755
# 26948                 300                835                621
# 24496                1138                845                250
#
#        ratings_five_zero                                             url  \
# 12552              13704  /games/the-legend-of-zelda-breath-of-the-wild/
# 19153               1877                              /games/dishonored/
# 30494               5250     /games/the-legend-of-zelda-ocarina-of-time/
# 33395                 25           /games/kaeru-no-tame-ni-kane-wa-naru/
# 27827               2513      /games/the-legend-of-zelda-the-wind-waker/
# 28345               1124                          /games/kingdom-hearts/
# 25654               2640                       /games/kingdom-hearts-ii/
# 7794                2256                           /games/disco-elysium/
# 26948                957                         /games/katamari-damacy/
# 24496                185   /games/the-legend-of-zelda-phantom-hourglass/
#
#        game_id
# 12552     7346
# 19153      533
# 30494     1029
# 33395    49078
# 27827     1033
# 28345     1219
# 25654     1221
# 7794     26472
# 26948     6453
# 24496     1037
#
# [10 rows x 26 columns]

# %%
model_predict(5919, topic_and_genre_model, final_data, X_train)
# Out:
#                         title   release_date  plays  playing  backlogs  \
# 5919                  FIFA 21  1602115200000   1600       39        57
# 11731        Everybody's Golf  1503964800000    337        9        95
# 2187                 NBA 2K23  1662595200000    550       81       120
# 14952                WWE 2K16  1445904000000    923        4        55
# 6189            PGA Tour 2K21  1597881600000    212       10       181
# 7580    Football Manager 2020  1574121600000    425       14       205
# 34143              Pilotwings   661737600000    920        6       224
# 1318                 WWE 2K23  1679011200000    306       72        39
# 9814                 NBA 2K19  1536624000000    744        5        35
# 2803   Nintendo Switch Sports  1651190400000   2000      105       277
#
#        wishlist                                   developers  avg_review  \
# 5919         20              [Electronic Arts, EA Vancouver]         2.5
# 11731        42  [Clap Hanz, Sony Interactive Entertainment]         3.7
# 2187         16                  [Visual Concepts, 2K Games]         2.7
# 14952        19                        [2K, Visual Concepts]         3.0
# 6189          8                             [HB Studios, 2K]         2.9
# 7580          5                         [Sports Interactive]         3.7
# 34143        65                       [Playtronic, Nintendo]         3.0
# 1318         53                  [2K Games, Visual Concepts]         3.5
# 9814          7                 [Visual Concepts, 2K Sports]         2.7
# 2803        393                                   [Nintendo]         3.0
#
#                    genres                                          platforms  \
# 5919   [Simulator, Sport]  [Windows PC, PlayStation 4, Xbox One, PlayStat...
# 11731  [Simulator, Sport]                                    [PlayStation 4]
# 2187   [Simulator, Sport]  [Windows PC, PlayStation 4, Xbox One, PlayStat...
# 14952  [Simulator, Sport]  [Windows PC, Xbox 360, PlayStation 4, PlayStat...
# 6189   [Simulator, Sport]  [Windows PC, PlayStation 4, Xbox One, Nintendo...
# 7580   [Simulator, Sport]                        [Windows PC, Google Stadia]
# 34143  [Simulator, Sport]  [Wii U, Super Famicom, SNES, Wii, New Nintendo...
# 1318   [Simulator, Sport]  [Windows PC, PlayStation 4, Xbox One, PlayStat...
# 9814   [Simulator, Sport]  [Windows PC, PlayStation 4, iOS, Xbox One, Nin...
# 2803   [Simulator, Sport]                                  [Nintendo Switch]
#
#        ... ratings_one_five  ratings_two_zero  ratings_two_five  \
# 5919   ...               90               176               211
# 11731  ...                1                 5                 7
# 2187   ...               25                52                54
# 14952  ...               31                51                94
# 6189   ...                5                13                34
# 7580   ...                6                 5                20
# 34143  ...               16                38                72
# 1318   ...                2                 5                19
# 9814   ...               38                73                80
# 2803   ...               40               112               158
#
#       ratings_three_zero  ratings_three_five  ratings_four_zero  \
# 5919                 255                 114                 70
# 11731                 39                  45                 66
# 2187                 108                  62                 42
# 14952                194                 119                 67
# 6189                  32                  34                 16
# 7580                  40                  68                106
# 34143                152                  92                 49
# 1318                  39                  81                 68
# 9814                 103                  77                 54
# 2803                 376                 245                115
#
#        ratings_four_five  ratings_five_zero                             url  \
# 5919                  18                 12                 /games/fifa-21/
# 11731                 19                 16      /games/everybodys-golf--1/
# 2187                   5                  8                /games/nba-2k23/
# 14952                 20                 13                /games/wwe-2k16/
# 6189                   3                  1           /games/pga-tour-2k21/
# 7580                  27                 24   /games/football-manager-2020/
# 34143                  6                 13              /games/pilotwings/
# 1318                  19                  8                /games/wwe-2k23/
# 9814                  12                  6                /games/nba-2k19/
# 2803                  29                 17  /games/nintendo-switch-sports/
#
#        game_id
# 5919    134101
# 11731    28187
# 2187    207393
# 14952    11057
# 6189    133939
# 7580    122080
# 34143     9619
# 1318    233028
# 9814    103218
# 2803    191408
#
# [10 rows x 26 columns]

# %%
model_predict(36255, topic_and_genre_model, final_data, X_train)
# Out:
#                                      title   release_date  plays  playing  \
# 36255                                Omori  1608854400000  11000     1400
# 15176                            Undertale  1442275200000  39000      907
# 813                           Sea of Stars  1693180800000   1200      960
# 7563   Bug Fables: The Everlasting Sapling  1574294400000   1500      179
# 5923                              Ikenfell  1602115200000    299       21
# 36514                       Grimm's Hollow  1572480000000    647       19
# 7284                                Temtem  1579564800000    753       98
# 3255               Pokémon Legends: Arceus  1643328000000  14000     1800
# 13424                            Persona 5  1473897600000  21000      772
# 7306                 Yakuza: Like a Dragon  1579132800000   8600     1100
#
#        backlogs  wishlist                                developers  \
# 36255      6700      5200                         [OMOCAT, PLAYISM]
# 15176      7400      2600                            [tobyfox, 8-4]
# 813        1900      2800                                [Sabotage]
# 7563       1600       704  [DANGEN Entertainment, Moonsprout Games]
# 5923        315       226        [Chevy Ray Johnston, Humble Games]
# 36514       384       109                             [ghosthunter]
# 7284        396       316               [CremaGames, Humble Bundle]
# 3255       3900      2700                    [Nintendo, Game Freak]
# 13424      3600      2100                   [Deep Silver, P Studio]
# 7306       6900      3600             [Sega, Ryū Ga Gotoku Studios]
#
#        avg_review                                        genres  \
# 36255         4.1  [Adventure, Indie, RPG, Turn Based Strategy]
# 15176         4.3  [Adventure, Indie, RPG, Turn Based Strategy]
# 813           3.9  [Adventure, Indie, RPG, Turn Based Strategy]
# 7563          4.1  [Adventure, Indie, RPG, Turn Based Strategy]
# 5923          3.7  [Adventure, Indie, RPG, Turn Based Strategy]
# 36514         3.6  [Adventure, Indie, RPG, Turn Based Strategy]
# 7284          3.0  [Adventure, Indie, RPG, Turn Based Strategy]
# 3255          3.7         [Adventure, RPG, Turn Based Strategy]
# 13424         4.1         [Adventure, RPG, Turn Based Strategy]
# 7306          4.3         [Adventure, RPG, Turn Based Strategy]
#
#                                                platforms  ...  \
# 36255  [Windows PC, Mac, PlayStation 4, Nintendo 3DS,...  ...
# 15176  [Windows PC, Mac, Linux, PlayStation 4, Xbox O...  ...
# 813    [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
# 7563   [Windows PC, PlayStation 4, Xbox One, Nintendo...  ...
# 5923   [Windows PC, Mac, PlayStation 4, Xbox One, Nin...  ...
# 36514                                       [Windows PC]  ...
# 7284   [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
# 3255                                   [Nintendo Switch]  ...
# 13424                     [PlayStation 4, PlayStation 3]  ...
# 7306   [Windows PC, PlayStation 4, Xbox One, PlayStat...  ...
#
#       ratings_one_five  ratings_two_zero  ratings_two_five ratings_three_zero  \
# 36255              104               191               254                491
# 15176              175               400               540               1492
# 813                  5                29                47                 75
# 7563                 5                18                20                 74
# 5923                 2                 7                12                 25
# 36514                2                 8                31                103
# 7284                16                58                60                110
# 3255               121               277               492               1195
# 13424              125               300               454               1067
# 7306                45               103               129                315
#
#        ratings_three_five  ratings_four_zero  ratings_four_five  \
# 36255                 766               1552               1587
# 15176                2521               5560               5488
# 813                   128                239                177
# 7563                   95                222                220
# 5923                   39                 56                 27
# 36514                 125                119                 40
# 7284                   78                 71                 21
# 3255                 1909               2627               1390
# 13424                1717               3420               3092
# 7306                  515               1308               1635
#
#        ratings_five_zero                                         url  game_id
# 36255               3009                               /games/omori/    26673
# 15176               9709                           /games/undertale/    12517
# 813                  172                        /games/sea-of-stars/   131890
# 7563                 208  /games/bug-fables-the-everlasting-sapling/   119190
# 5923                  24                            /games/ikenfell/    23873
# 36514                 34                       /games/grimms-hollow/   125110
# 7284                  10                              /games/temtem/   100357
# 3255                 779              /games/pokemon-legends-arceus/   144054
# 13424               3687                           /games/persona-5/     9927
# 7306                2077                /games/yakuza-like-a-dragon/    36550
#
# [10 rows x 26 columns]

# %% [markdown]
# # Conclusion
#
# Model is performing better, as sport games are being reccomended for FIFA, and Horror/Dark games are being recommended for Omori
# However, Breath of The Wild Still Brings back a lot of Zelda games, that vary a lot in style. Despite being the same genre and basic storyline.
#
# ## Next steps
#
# Try get more data to suppliment the model. There is a free API called IGDB that we will use.
